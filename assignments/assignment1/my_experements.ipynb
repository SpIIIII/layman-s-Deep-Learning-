# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (7,5)

# %%
X, y = make_classification(n_samples=1000, n_features=2, n_redundant=0,
                           random_state=2019, n_clusters_per_class=1,
                           n_classes=3)

# %%
print(X)
# Out:
# [[ 0.56865069  0.84030562]
#  [ 0.82335461  0.78060357]
#  [ 0.88144629 -0.87466142]
#  ...
#  [ 0.6154195   2.21211485]
#  [ 0.91697291  1.7117501 ]
#  [ 0.93685928 -1.05311514]]

# %%
plt.style.use('seaborn-white')
plt.scatter(X[:,0],X[:,1],c=y,cmap = plt.cm.viridis,linewidth = 0)

plt.show()
